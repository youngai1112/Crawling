# %%
import requests
from bs4 import BeautifulSoup

url = "https://comic.naver.com/webtoon/weekday"
res = requests.get(url)
res.raise_for_status()

soup = BeautifulSoup(res.text, "lxml")
# soup 문서 전체 중에서 태그명이 a이고, class 속성이 title인 값을 모두 불러옴
# 네이버 웹툰 전체 목록 가져오기
cartoons = soup.find_all("a", attrs={"class":"title"})
# class 속성이 title인 모든 "a" element를 반환
for cartoon in cartoons:
    print(cartoon.get_text())
# Out:
# 쇼미더럭키짱!
# 참교육
# 신의 탑
# 2022 서브병에 빠지다!
# 퀘스트지상주의
# 소녀의 세계
# 장씨세가 호위무사
# 백수세끼
# 팔이피플
# 앵무살수
# 잔불의 기사
# 만렙돌파
# 리턴 투 플레이어
# 별을 쫓는 소년들
# 요리GO
# 똑 닮은 딸
# 더블클릭
# 히어로메이커
# 칼가는 소녀
# 물어보는 사이
# 평범한 8반
# 결혼생활 그림일기
# 황제와의 하룻밤
# 디나운스
# 꼬리잡기
# 찌질하지만 로맨스는 하고 싶어
# 신군
# 나만의 고막남친
# 아는 여자애
# 꿈의 기업
# 싸이코 리벤지
# 아, 쫌 참으세요 영주님!
# 뷰티풀 군바리
# 이별 후 사내 결혼
# 오빠집이 비어서
# 제왕: 빛과 그림자
# 장난감
# 이제야 연애
# 와이키키 뱀파이어
# 오로지 오로라
# 말박왕
# 또다시, 계약 부부
# 바퀴
# 레지나레나 - 용서받지 못한 그대에게
# 야생천사 보호구역
# 원작은 완결난 지 한참 됐습니다만
# 최후의 금빛아이
# 원하는 건 너 하나
# 악녀 18세 공략기
# 이중첩자
# 왕따협상
# 달로 만든 아이
# 모스크바의 여명
# 홍천기
# 중독연구소
# 기사님을 지켜줘
# 그림자 신부
# 마지막 지수
# 사랑의 헌옷수거함
# 개밥 먹는 남자
# 모락모락 왕세자님
# 바로 보지 않는
# 트리거
# 역주행!
# 결백한 사람은 없다
# 사막에 핀 달
# 남주서치
# 보살님이 캐리해!
# 헬로맨스
# 슈퍼스타 천대리
# 쇼미더럭키짱!
# 여신강림
# 김부장
# 2022 서브병에 빠지다!
# 1을 줄게
# 한림체육관
# 멸망 이후의 세계
# 내가 키운 S급들
# 사신소년
# 중증외상센터 : 골든 아워
# 용사가 돌아왔다
# 하루만 네가 되고 싶어
# 신도림
# 삼국지톡
# 니나의 마법서랍
# 엽총소년
# 랜덤채팅의 그녀!
# 헬58
# 하북팽가 막내아들
# 집이 없어
# 원주민 공포만화
# 소극적 인간
# 윌유메리미
# 덴큐
# 한입만!
# 위아더좀비
# 몬스터
# 늑대처럼 홀로
# 애옹식당
# 하우스키퍼
# 빌런투킬
# 택배 왔습니다
# 견우와 선녀
# 100
# 짝사랑의 마침표
# 올가미
# 미물
# 용왕님의 셰프가 되었습니다
# 빅맨
# 은주의 방 2~3부
# 플레이, 플리
# 또 다른 사랑
# 대공님, 실수였어요!
# 이상형은 아닙니다
# 나타나주세요!
# 정년이
# 제로게임
# 숲속의 담
# 연우의 순정
# 오파츠
# 나의 플랏메이트
# 열녀박씨 계약결혼뎐
# 미신
# 시벨롬 리스트
# 그녀석 정복기
# 대신 심부름을 해다오
# 나는 어디에나 있다
# 그 남주와 이별하는 방법
# 필리아로제 - 가시왕관의 예언
# 기계증식증
# 급식러너
# NG불가
# 이븐 모어
# 프린스 메이커
# 풋내기들
# 교환학생
# 고등매직
# 다꾸남
# 피로만땅
# 찐:종합게임동아리
# 하나in세인
# 태시트
# 쇼미더럭키짱!
# 전지적 독자 시점
# 화산귀환
# 헬퍼 2 : 킬베로스
# 먹는 인생
# 캐슬
# 튜토리얼 탑의 고인물
# 여고생 드래곤
# 조조코믹스
# 남주의 첫날밤을 가져버렸다
# 일렉시드
# 여주실격!
# 66666년 만에 환생한 흑마법사
# 나쁜사람
# 내 남편과 결혼해줘
# 연놈
# 고삼무쌍
# 엔딩 후 서브남을 주웠다
# 세상은 돈과 권력
# 마른 가지에 바람처럼
# 빌드업
# 미래의 골동품 가게
# 가짜 동맹
# 사상최강
# 판타지 여동생!
# 더 퀸즈
# 귀곡의 문
# 아도나이
# 얼굴천재
# 하렘의 남자들
# 탈영일지
# 고등단편.zip
# 언덕 위의 제임스
# 관종교장
# 칼부림
# 베스트 프렌드
# 쓰레기는 쓰레기통에!
# 밤낚시
# 헤어지면 죽음
# 인과관계
# 마녀와 용의 신혼일기
# 수요웹툰의 나강림
# 오징어도 사랑이 되나요?
# 방탈출
# 로어 올림푸스
# 블랙홀과 3만원
# 괴물공작의 딸
# 변방의 외노자
# 반귀
# 내가 죽기로 결심한 것은
# 범이올시다!
# 고민남녀 방백커플
# 하지만 너는 2D잖아
# 잿빛도 색이다
# 필생기
# 화가 살리에르
# 혁명 뒤 공주는
# 두 번 사는 프로듀서
# 사랑과 평강의 온달!
# 구사일생 로맨스
# 스캔들
# 반짝반짝 작은 눈
# 무용과 남학생
# 웰컴 온보드
# 해귀
# 뱀은 꽃을 먹는가
# 구주
# 오직, 밝은 미래
# 재난소년
# 수호하는 너에게
# 시효완성
# 나의 계절
# 독립일기
# 쇼미더럭키짱!
# 더 복서
# 연애혁명
# 나노마신
# 기기괴괴
# 신림/남/22
# 이두나!
# 나 혼자 네크로맨서
# 현실퀘스트
# 특수청소
# 천마육성
# 정글쥬스
# 무사만리행
# 별을 삼킨 너에게
# 겟백
# 포식동물
# 국세청 망나니
# 묵시의 인플루언서
# 하드캐리
# 쿠베라
# 꽃만 키우는데 너무강함
# 불편한 관계
# 최강전설 강해효
# 오빠세끼
# 가족같은 XX
# 트롤트랩
# 만능잡캐
# 신비
# 갓트
# 흑막 여주가 날 새엄마로 만들려고 해
# 완벽한 결혼의 정석
# 마왕까지 한 걸음
# 만물의 영장
# 선남친 후연애
# 가상&RPG
# 마계인섬
# 안개무덤
# 네가 죽기를 바랄 때가 있었다
# 나쁜 마법사의 꿈
# 온에어
# 시월드 판타지
# 이계 무슨 황비
# 마법사랑해
# 던전 씹어먹는 아티팩트
# 침묵의 밤
# 그 개, 만두
# 킬더킹
# 마녀의 심판은 꽃이 된다
# 달의 요람
# 야만의 시대
# 해시의 신루
# 루커피쳐
# 세라미안
# THE 런웨이
# 소녀180
# 어차피 남편은!
# 그 황제가 시곗바늘을 되돌린 사연
# 보물과 괴물의 도시
# 배트맨: 웨인 패밀리 어드벤처
# 소년의 기록
# 환상연가
# 혼모노트
# 아빠같은 남자
# 성스러운 아이돌
# 유리와 유리와 유리
# 카루나
# 온새미로
# 폭탄주먹 변대장
# 돌아온 여기사
# 평범한 낙원
# 어느날 네가 떠올라!
# 모어 라이프
# 멸망X초이스
# 쇼미더럭키짱!
# 외모지상주의
# 갓 오브 하이스쿨
# 내과 박원장
# 나 혼자 만렙 뉴비
# 2022 서브병에 빠지다!
# 광마회귀
# 데드퀸
# 재혼 황후
# 1초
# 어쩌다보니 천생연분
# 개를 낳았다
# 죽지 않으려면
# 삼국지톡
# 세기말 풋사과 보습학원
# 낙향문사전
# 서울역 드루이드
# 더 게이머
# 상남자
# 소극적 인간
# 피와 나비
# 푸쉬오프
# 뫼신 사냥꾼
# 쌈빡
# 상위1%
# 구남친이 내게 반했다
# 여성전용헬스장 진달래짐
# 플레이어
# 그렇고 그런 바람에
# 히어로 킬러
# A.I. 닥터
# 역대급 영지 설계사
# 희란국연가
# 말년용사
# 미혼남녀의 효율적 만남
# 그 기사가 레이디로 사는 법
# 여우놀이
# 스포
# 버그: 스티그마
# 후덜덜덜 남극전자
# 식인귀
# 사람의 조각
# 도무지 그애는
# 엽사:요괴사냥꾼
# 너의 미소가 함정
# 기후변화 그림일기
# 골든 체인지
# 감자마을
# 그들이 사귀는 세상
# 미친 후작을 길들이고 말았다
# 주님, 악마가 되게 해주세요!
# 오!너의 리스크
# 이게 아닌데
# 백년게임
# 네버엔딩달링
# 여름여자 하보이
# 인피니티
# 로판 빙의 만화
# 빨간맛 로맨스
# 트럼프
# 태권보이
# 악몽일기
# 달이 없는 나라
# 짝사랑 마들렌
# 리트리츠
# 아찔한 전남편
# 재앙의 날
# 꽃 피우는 남자
# 나쁜 쪽으로
# 히트포인트
# 합법해적 파르페
# 킬러방 : 퍼스트 킬
# 행운을 빌어요, 용사님!
# 강림전기 개정기
# 팬시X팬시
# 다름이 아니라
# 프리드로우
# 신림/남/22
# 취사병 전설이 되다
# 2022 서브병에 빠지다!
# 은탄
# 먹는 인생
# 스퍼맨 : 전하지 못한 이야기
# 초인의 시대
# 여고생 드래곤
# 조조코믹스
# 망나니 소교주로 환생했다
# 니나의 마법서랍
# 스터디그룹
# 아사
# 윌유메리미
# 아홉수 우리들
# 나이트런
# 반드시 해피엔딩
# 존잘주의
# 7FATES: CHAKHO
# 청춘 블라썸
# 힙한남자
# 나태 공자, 노력 천재 되다
# 소공녀 민트
# 나를 바꿔줘
# 용사참수인
# 최면학교
# 적월의 나라
# 일상이 무너졌다
# 마법사가 죽음을 맞이하는 방법
# 피라미드 게임
# 어글리후드
# 탑코너
# 좀비 파이트
# 태백 : 튜토리얼 맨
# 왕년엔 용사님
# 좋아해 아니 싫어해
# 감 비서가 고장났다
# 최강부캐
# 은둔코인
# 엑스애쉬
# 홍시는 날 좋아해!
# 배달의 신
# 공유몽
# 메트로헌터
# 소년 검사
# 내게 필요한 NO맨스
# 봐선 안되는 것
# 남편을 만렙으로 키우려 합니다
# 물위의 우리
# 저무는 해, 시린 눈
# 전생연분
# 지구식 구원자 전형
# 보듬보듬
# 도사 가온
# 중매쟁이 아가 황녀님
# 키스 식스 센스
# 팔려 온 신부
# 묘령의 황자
# 같은 학교 친구
# 좋은데 어떡해
# 주욱 같은 하루
# 홍대 바이브
# 오늘부터 천생연분
# 사서고생!
# 더 나우
# 안녕, 이바다씨
# 스트릿 워크아웃
# 숨겨진 성녀
# 밤을 깨우는 마법
# 인간졸업
# 아침을 지나 밤으로
# 광해의 연인
# 2-3승강장
# 나를 길들여 봐, 차비서
# 아가사
# 먹지마세요
# 실버 쥬얼
# 독립일기
# 싸움독학
# 입학용병
# 열렙전사
# 약한영웅
# 투신전생기
# 존망코인
# 이번 생도 잘 부탁해
# 그 해 우리는 - 초여름이 좋아!
# 수희0(tngmlek0)
# 일타강사 백사부
# 무서운게 딱좋아!
# 어느날 갑자기 서울은
# 소녀재판
# 곱게 키웠더니, 짐승
# 오로지 너를 이기고 싶어
# 별이삼샵
# 내일
# 테러대부활
# 살아남은 로맨스
# 판사 이한영
# 경자 전성시대
# 동생친구
# 합격시켜주세용
# DARK MOON: 달의 제단
# 가비지타임
# 벚꽃이 흩날릴 무렵
# 나의 작은 서점
# 철수와 영희 이야기
# 장미같은 소리
# 위험한 남편을 길들이는 법
# 블러드 리벤저
# 로어 올림푸스
# 시월드가 내게 집착한다
# 위닝샷!
# 학교정벌
# 사실 마법이었던 거임
# 장풍전
# 생존고백
# 생존로그
# 전설의 화석
# 여우애담
# 예쁜 사나이
# 천치전능
# 몸이 바뀌는 사정
# 돌&아이
# 후궁 스캔들
# 사람은 고쳐 쓰는 게 아니야!
# 굿 리스너
# 구해줘, 호구!
# 신이 담긴 아이
# 오른눈이 보는 세계
# 조선여우스캔들
# 불순물
# 보스의 노골적 취향
# 취향 소개소
# 결혼까지 망상했어!
# 혀로 만난 사이
# 황제에게 하트를 심어주세요
# 라커, 오프너
# 데이즈
# 거래하실래요?
# 당신의 여자가 되고 싶어요
# 보통아이
# 가짜인간
# 랑데뷰
# 푸른불꽃
# 데빌샷
# 독신마법사 기숙아파트
# 샤인 스타
# 다시 또 봄
# 짝사랑의 유서
# 제타
# 패션쇼

# %%
url = "https://comic.naver.com/webtoon/list?titleId=748105&weekday=sun"
res = requests.get(url)
res.raise_for_status()

soup = BeautifulSoup(res.text, "lxml")
cartoons = soup.find_all("td", attrs={"class":"title"})
title = cartoons[0].get_text()
link = cartoons[0].a["href"]
print(title)
print("https://comic.naver.com" + link)
# Out:
# 시즌2 49화 설 연휴는 이렇게 (1)
#
#
# https://comic.naver.com/webtoon/detail?titleId=748105&no=152&weekday=sun

# %%
for cartoon in cartoons:
    title = cartoon.a.get_text()
    link = "https://comic.naver.com" + cartoon.a["href"]
    print(title, link)
# Out:
# 시즌2 49화 설 연휴는 이렇게 (1) https://comic.naver.com/webtoon/detail?titleId=748105&no=152&weekday=sun
# 시즌2 48화 제발 드셔주세요 https://comic.naver.com/webtoon/detail?titleId=748105&no=151&weekday=sun
# 시즌2 47화 결막염 https://comic.naver.com/webtoon/detail?titleId=748105&no=150&weekday=sun
# 시즌2 46화 코로나 시대에 적응하는 법 https://comic.naver.com/webtoon/detail?titleId=748105&no=149&weekday=sun
# 시즌2 45화 엄마 생일 미역국 끓이기 https://comic.naver.com/webtoon/detail?titleId=748105&no=148&weekday=sun
# 시즌2 44화 신년 맞이 스케일링 https://comic.naver.com/webtoon/detail?titleId=748105&no=147&weekday=sun
# 시즌2 43화 부모님 가르쳐드리기 https://comic.naver.com/webtoon/detail?titleId=748105&no=146&weekday=sun
# 시즌2 42화 시간제 캠핑 https://comic.naver.com/webtoon/detail?titleId=748105&no=145&weekday=sun
# 시즌2 41화 우리 집 산타 https://comic.naver.com/webtoon/detail?titleId=748105&no=144&weekday=sun
# 시즌2 40화 깐부 https://comic.naver.com/webtoon/detail?titleId=748105&no=143&weekday=sun
